# %%
import numpy as np
import pandas as pd

# %%
pd.read_csv('zoo.csv', delimiter=',') #reading a csv file ;) THIS is a DATAFRAME (2d or more data). 1d array is SERIES
# Out:
#       animal  uniq_id  water_need
# 0   elephant     1001         500
# 1   elephant     1002         600
# 2   elephant     1003         550
# 3      tiger     1004         300
# 4      tiger     1005         320
# 5      tiger     1006         330
# 6      tiger     1007         290
# 7      tiger     1008         310
# 8      zebra     1009         200
# 9      zebra     1010         220
# 10     zebra     1011         240
# 11     zebra     1012         230
# 12     zebra     1013         220
# 13     zebra     1014         100
# 14     zebra     1015          80
# 15      lion     1016         420
# 16      lion     1017         600
# 17      lion     1018         500
# 18      lion     1019         390
# 19  kangaroo     1020         410
# 20  kangaroo     1021         430
# 21  kangaroo     1022         410

# %%
pd.read_csv('pandas_tutorial_read.csv', delimiter = ';')
# Out:
#       2018-01-01 00:01:01  read  country_7  2458151261      SEO  North America
# 0     2018-01-01 00:03:20  read  country_7  2458151262      SEO  South America
# 1     2018-01-01 00:04:01  read  country_7  2458151263  AdWords         Africa
# 2     2018-01-01 00:04:02  read  country_7  2458151264  AdWords         Europe
# 3     2018-01-01 00:05:03  read  country_8  2458151265   Reddit  North America
# 4     2018-01-01 00:05:42  read  country_6  2458151266   Reddit  North America
# 5     2018-01-01 00:06:06  read  country_2  2458151267   Reddit         Europe
# 6     2018-01-01 00:06:15  read  country_6  2458151268  AdWords         Europe
# 7     2018-01-01 00:07:21  read  country_7  2458151269  AdWords  North America
# 8     2018-01-01 00:07:29  read  country_5  2458151270   Reddit  North America
# 9     2018-01-01 00:07:57  read  country_5  2458151271  AdWords           Asia
# 10    2018-01-01 00:08:57  read  country_7  2458151272      SEO      Australia
# ...

# %%
#Setting a header for the pandas dataframe
pd.read_csv('pandas_tutorial_read.csv', 
            delimiter=';', 
            names = ['my_datetime', 'event', 'country', 'user_id', 'source', 'topic'])
# Out:
#               my_datetime event    country     user_id   source          topic
# 0     2018-01-01 00:01:01  read  country_7  2458151261      SEO  North America
# 1     2018-01-01 00:03:20  read  country_7  2458151262      SEO  South America
# 2     2018-01-01 00:04:01  read  country_7  2458151263  AdWords         Africa
# 3     2018-01-01 00:04:02  read  country_7  2458151264  AdWords         Europe
# 4     2018-01-01 00:05:03  read  country_8  2458151265   Reddit  North America
# 5     2018-01-01 00:05:42  read  country_6  2458151266   Reddit  North America
# 6     2018-01-01 00:06:06  read  country_2  2458151267   Reddit         Europe
# 7     2018-01-01 00:06:15  read  country_6  2458151268  AdWords         Europe
# 8     2018-01-01 00:07:21  read  country_7  2458151269  AdWords  North America
# 9     2018-01-01 00:07:29  read  country_5  2458151270   Reddit  North America
# 10    2018-01-01 00:07:57  read  country_5  2458151271  AdWords           Asia
# ...

# %%
#store in a variable
article_read = pd.read_csv('pandas_tutorial_read.csv',
                           delimiter=';',
                           names = ['my_datetime', 'event', 'country', 'user_id', 'source', 'topic'])

# %%
article_read
# Out:
#               my_datetime event    country     user_id   source          topic
# 0     2018-01-01 00:01:01  read  country_7  2458151261      SEO  North America
# 1     2018-01-01 00:03:20  read  country_7  2458151262      SEO  South America
# 2     2018-01-01 00:04:01  read  country_7  2458151263  AdWords         Africa
# 3     2018-01-01 00:04:02  read  country_7  2458151264  AdWords         Europe
# 4     2018-01-01 00:05:03  read  country_8  2458151265   Reddit  North America
# 5     2018-01-01 00:05:42  read  country_6  2458151266   Reddit  North America
# 6     2018-01-01 00:06:06  read  country_2  2458151267   Reddit         Europe
# 7     2018-01-01 00:06:15  read  country_6  2458151268  AdWords         Europe
# 8     2018-01-01 00:07:21  read  country_7  2458151269  AdWords  North America
# 9     2018-01-01 00:07:29  read  country_5  2458151270   Reddit  North America
# 10    2018-01-01 00:07:57  read  country_5  2458151271  AdWords           Asia
# ...

# %%
article_read.head() #first 5 lines
# Out:
#            my_datetime event    country     user_id   source          topic
# 0  2018-01-01 00:01:01  read  country_7  2458151261      SEO  North America
# 1  2018-01-01 00:03:20  read  country_7  2458151262      SEO  South America
# 2  2018-01-01 00:04:01  read  country_7  2458151263  AdWords         Africa
# 3  2018-01-01 00:04:02  read  country_7  2458151264  AdWords         Europe
# 4  2018-01-01 00:05:03  read  country_8  2458151265   Reddit  North America

# %%
article_read.tail() #last 5 lines
# Out:
#               my_datetime event    country     user_id   source          topic
# 1790  2018-01-01 23:57:14  read  country_2  2458153051  AdWords  North America
# 1791  2018-01-01 23:58:33  read  country_8  2458153052      SEO           Asia
# 1792  2018-01-01 23:59:36  read  country_6  2458153053   Reddit           Asia
# 1793  2018-01-01 23:59:36  read  country_7  2458153054  AdWords         Europe
# 1794  2018-01-01 23:59:38  read  country_5  2458153055   Reddit           Asia

# %%
article_read.sample(3) #rand 3 lines
# Out:
#               my_datetime event    country     user_id   source          topic
# 5     2018-01-01 00:05:42  read  country_6  2458151266   Reddit  North America
# 927   2018-01-01 12:23:21  read  country_4  2458152188   Reddit           Asia
# 1717  2018-01-01 23:08:49  read  country_7  2458152978  AdWords      Australia

# %%
article_read[['country', 'user_id']] #specific columns
# Out:
#         country     user_id
# 0     country_7  2458151261
# 1     country_7  2458151262
# 2     country_7  2458151263
# 3     country_7  2458151264
# 4     country_8  2458151265
# 5     country_6  2458151266
# 6     country_2  2458151267
# 7     country_6  2458151268
# 8     country_7  2458151269
# 9     country_5  2458151270
# 10    country_5  2458151271
# 11    country_7  2458151272
# 12    country_5  2458151273
# 13    country_2  2458151274
# 14    country_7  2458151275
# 15    country_7  2458151276
# 16    country_8  2458151277
# 17    country_2  2458151278
# 18    country_4  2458151279
# 19    country_2  2458151280
# 20    country_2  2458151281
# 21    country_7  2458151282
# 22    country_2  2458151283
# 23    country_2  2458151284
# 24    country_7  2458151285
# 25    country_2  2458151286
# 26    country_5  2458151287
# 27    country_2  2458151288
# 28    country_2  2458151289
# 29    country_7  2458151290
# ...         ...         ...
# 1765  country_2  2458153026
# ...

# %%
article_read.user_id
# Out:
# 0       2458151261
# 1       2458151262
# 2       2458151263
# 3       2458151264
# 4       2458151265
# 5       2458151266
# 6       2458151267
# 7       2458151268
# 8       2458151269
# 9       2458151270
# 10      2458151271
# 11      2458151272
# 12      2458151273
# 13      2458151274
# 14      2458151275
# 15      2458151276
# 16      2458151277
# 17      2458151278
# 18      2458151279
# 19      2458151280
# 20      2458151281
# 21      2458151282
# 22      2458151283
# 23      2458151284
# 24      2458151285
# 25      2458151286
# 26      2458151287
# 27      2458151288
# 28      2458151289
# 29      2458151290
#            ...
# 1765    2458153026
# 1766    2458153027
# 1767    2458153028
# 1768    2458153029
# 1769    2458153030
# 1770    2458153031
# 1771    2458153032
# 1772    2458153033
# 1773    2458153034
# 1774    2458153035
# 1775    2458153036
# 1776    2458153037
# 1777    2458153038
# 1778    2458153039
# 1779    2458153040
# 1780    2458153041
# ...

# %%
article_read[['user_id']]
# Out:
#          user_id
# 0     2458151261
# 1     2458151262
# 2     2458151263
# 3     2458151264
# 4     2458151265
# 5     2458151266
# 6     2458151267
# 7     2458151268
# 8     2458151269
# 9     2458151270
# 10    2458151271
# 11    2458151272
# 12    2458151273
# 13    2458151274
# 14    2458151275
# 15    2458151276
# 16    2458151277
# 17    2458151278
# 18    2458151279
# 19    2458151280
# 20    2458151281
# 21    2458151282
# 22    2458151283
# 23    2458151284
# 24    2458151285
# 25    2458151286
# 26    2458151287
# 27    2458151288
# 28    2458151289
# 29    2458151290
# ...          ...
# 1765  2458153026
# 1766  2458153027
# 1767  2458153028
# 1768  2458153029
# 1769  2458153030
# 1770  2458153031
# 1771  2458153032
# 1772  2458153033
# 1773  2458153034
# 1774  2458153035
# 1775  2458153036
# 1776  2458153037
# 1777  2458153038
# 1778  2458153039
# 1779  2458153040
# 1780  2458153041
# 1781  2458153042
# 1782  2458153043
# 1783  2458153044
# 1784  2458153045
# ...

# %%
article_read[article_read.topic == 'Africa'] #select all instances with topic equals to 'Africa'
# Out:
#               my_datetime event    country     user_id   source   topic
# 2     2018-01-01 00:04:01  read  country_7  2458151263  AdWords  Africa
# 14    2018-01-01 00:11:06  read  country_7  2458151275   Reddit  Africa
# 21    2018-01-01 00:15:50  read  country_7  2458151282   Reddit  Africa
# 24    2018-01-01 00:17:58  read  country_7  2458151285   Reddit  Africa
# 52    2018-01-01 00:44:47  read  country_3  2458151313   Reddit  Africa
# 68    2018-01-01 01:02:40  read  country_7  2458151329  AdWords  Africa
# 77    2018-01-01 01:12:51  read  country_4  2458151338      SEO  Africa
# 78    2018-01-01 01:13:01  read  country_8  2458151339   Reddit  Africa
# 80    2018-01-01 01:14:24  read  country_4  2458151341      SEO  Africa
# 82    2018-01-01 01:17:10  read  country_2  2458151343   Reddit  Africa
# 95    2018-01-01 01:23:44  read  country_6  2458151356   Reddit  Africa
# 110   2018-01-01 01:37:56  read  country_2  2458151371      SEO  Africa
# ...

# %%
article_read.topic == 'Africa'
# Out:
# 0       False
# 1       False
# 2        True
# 3       False
# 4       False
# 5       False
# 6       False
# 7       False
# 8       False
# 9       False
# 10      False
# 11      False
# 12      False
# 13      False
# 14       True
# 15      False
# 16      False
# 17      False
# 18      False
# 19      False
# 20      False
# 21       True
# 22      False
# 23      False
# 24       True
# 25      False
# 26      False
# 27      False
# 28      False
# 29      False
#         ...
# 1765     True
# 1766    False
# 1767    False
# 1768    False
# 1769    False
# 1770    False
# 1771     True
# 1772    False
# 1773    False
# 1774    False
# 1775    False
# 1776    False
# 1777    False
# 1778    False
# 1779    False
# 1780     True
# 1781    False
# 1782    False
# 1783    False
# 1784    False
# 1785     True
# 1786    False
# 1787    False
# 1788    False
# 1789    False
# 1790    False
# 1791    False
# 1792    False
# 1793    False
# 1794    False
# ...

# %%
article_read.head()[['topic', 'country']] #USING TWO FUNCTIONS. AFTER EACH OTHER
# Out:
#            topic    country
# 0  North America  country_7
# 1  South America  country_7
# 2         Africa  country_7
# 3         Europe  country_7
# 4  North America  country_8

# %%
article_read[['topic', 'country']].head() #ITS THE SAME
# Out:
#            topic    country
# 0  North America  country_7
# 1  South America  country_7
# 2         Africa  country_7
# 3         Europe  country_7
# 4  North America  country_8

# %%
#Select the user_id, the country and the topic columns for 
#the users who are from country_2! Print the first five rows only!
article_read [article_read.country == 'country_2'][['user_id', 'country', 'topic']].head()
# Out:
#        user_id    country   topic
# 6   2458151267  country_2  Europe
# 13  2458151274  country_2  Europe
# 17  2458151278  country_2    Asia
# 19  2458151280  country_2    Asia
# 20  2458151281  country_2    Asia

# %%
#you can store steps of the filter (each filter) in variables
article_read_filtered_country = article_read[article_read.country == 'country_2']
article_read_filtered_columns = article_read_filtered_country[['user_id', 'country', 'topic']]
article_read_filtered_final_head = article_read_filtered_columns.head()

# %%
article_read_filtered_final_head
# Out:
#        user_id    country   topic
# 6   2458151267  country_2  Europe
# 13  2458151274  country_2  Europe
# 17  2458151278  country_2    Asia
# 19  2458151280  country_2    Asia
# 20  2458151281  country_2    Asia
