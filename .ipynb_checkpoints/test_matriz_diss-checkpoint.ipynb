# %%
import pandas as pd
import numpy as np

# %%
matriz_dis = pd.read_csv('Matriz1.csv', delimiter=',', header=None )

# %%
matriz_dis
# Out:
#            0          1          2          3          4          5     \
# 0      0.000000   8.977333  10.263847   9.722229   8.973301  17.292143
# 1      8.977333   0.000000   8.139615   8.781957   6.970905  13.584608
# 2     10.263847   8.139615   0.000000   8.688969   9.069844  15.706521
# 3      9.722229   8.781957   8.688969   0.000000   9.242096  13.282870
# 4      8.973301   6.970905   9.069844   9.242096   0.000000  13.187478
# 5     17.292143  13.584608  15.706521  13.282870  13.187478   0.000000
# 6      6.422603   8.823310  11.218851  10.933403   9.254862  17.280759
# 7      6.927215   8.792317   9.835372  10.412164   6.129436  15.290110
# 8      8.121964  11.483614  14.219965  14.341733  12.251797  19.369463
# 9      8.977921   7.710041   9.256854   9.208244   9.929201  16.478535
# 10     9.136185   7.562398   8.605243   7.891395   6.080476  13.665347
# 11     9.621355   9.394456   9.177576   7.092028  10.167481  15.573312
# ...

# %%
array = np.array([[2,3,5,4]])
array
# Out:
# array([[2, 3, 5, 4]])

# %%
np.nansum(array)
# Out:
# 14
